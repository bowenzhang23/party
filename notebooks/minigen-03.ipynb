# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

import sys
sys.path.append(r"../src/")
from party.histogram import *
from party.vector import *

# %%
# detailed examples in minigen-03.py
ecm_hat = np.loadtxt("../minigen/outputs/pp_zy_mumu_ecm_hat.txt")
h_m = make_hist1d(ecm_hat, 100, 60, 200)

plt.figure()
h_m.plot(label="", color="black", density=False)
plt.xlabel(r"$E_{CM}$ [GeV]")
plt.ylabel("Events")
plt.yscale("log")
plt.ylim(1, 1e4)
plt.show()
